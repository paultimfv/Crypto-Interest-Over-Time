# %%
import requests
import pandas as pd
from pytrends.request import TrendReq

# %%
pytrends = TrendReq(hl='en-US', tz=360)

#build payload for last year of data
kw_list = ['Crypto']
pytrends.build_payload(kw_list,
                        cat=0,
                        timeframe='today 5-y',
                        geo='US',
                        gprop=''
                        )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['Blockchain', 'Crypto']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 5-y',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['Stablecoin']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 5-y',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['defi']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 12-m',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['defi']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 5-y',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['uniswap', 'defi']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 5-y',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['defi', 'nft']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 5-y',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['defi', 'nft']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 12-m',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['ethereum', 'nft']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 5-y',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['solana']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 5-y',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['solana']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 12-m',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['ethereum', 'arbitrum', 'polygon', 'optimism', 'solana']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 12-m',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['ethereum', 'bitcoin']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 5-y',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>

# %%
kw_list = ['MEV']
pytrends.build_payload(kw_list,
                       cat=0,
                       timeframe='today 5-y',
                       geo='',
                       gprop=''
                       )

interest_over_time = pytrends.interest_over_time()
interest_over_time.plot()
# Out:
# <Axes: xlabel='date'>
